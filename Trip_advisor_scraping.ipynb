# %%
from bs4 import BeautifulSoup
import lxml
import requests
import pandas as pd
import numpy as np
from time import sleep
from warnings import warn
from random import randint
from time import time
from requests import get
from IPython.core.display import clear_output
import urllib.request

# %%
base_url = 'https://www.tripadvisor.com/Attraction_Review-g60823-d292269-Reviews-John_F_Kennedy_National_Historic_Site-Brookline_Massachusetts.html'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}

# %%
page = urllib.request.urlopen(base_url)

# %%
#page = requests.get(base_url)

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="https://static.tacdn.com/favicon.ico?v2" id="favicon" rel="icon" type="image/x-icon"/>
#   <link color="#000000" href="https://static.tacdn.com/img2/brand_refresh/application_icons/mask-icon.svg" rel="mask-icon" sizes="any"/>
#   <meta content="#34e0a1" name="theme-color"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <script type="text/javascript">
#    window.taRollupsAreAsync = true;
#   </script>
#   <link crossorigin="" href="https://static.tacdn.com/css2/webfonts/TripSans/TripSans.css?v1.002" rel="stylesheet"/>
#   <title>
#    John F. Kennedy National Historic Site (Brookline) - 2020 All You Need to Know BEFORE You Go (with Photos) - Tripadvisor
#   </title>
#   <meta content="TripAdvisor" property="al:ios:app_name"/>
#   <meta content="284876795" property="al:ios:app_store_id"/>
# ...

# %%
results = soup.find(id='taplc_community-content_ar_responsive_0')

# %%
print(results.prettify())
# Out:
# <div class="ppr_rup ppr_priv_community-content" data-placement-name="community-content:ar_responsive" id="taplc_community-content_ar_responsive_0">
#  <div class="react-container" data-component="@ta/attractions.community-content" data-component-props="page-manifest" id="component_18">
#   <div class="_1nLZ9CnX" data-section-signature="community" data-tab="TABS_REVIEWS" id="REVIEWS">
#    <div class="FvPuYHkq">
#     <span class="_2GIfqQkr _2-zZAhSq sLZhlLAo Ls68q8e7">
#      <span class="ui_icon pencil-paper _3HDPvvJK">
#      </span>
#      <span class="">
#       <span class="_1yuvE2vR">
#        216
#       </span>
#       <span class="pZzTY-B7">
#        Reviews
#       </span>
#      </span>
#     </span>
#     <span class="_2GIfqQkr _2-zZAhSq Ls68q8e7">
#      <span class="ui_icon forums _3HDPvvJK">
#      </span>
#      <span class="">
#       <span class="_1yuvE2vR">
#        4
#       </span>
#       <span class="pZzTY-B7">
#        Q&amp;A
#       </span>
#      </span>
# ...

# %%
divis = soup.find_all('div')
for divi in divis:
    print(divi.prettify())
# Out:
# <div class="ppr_rup ppr_priv_unsupported_browser_messaging" data-placement-name="unsupported_browser_messaging" id="taplc_unsupported_browser_messaging_0">
#  <div class="unsupportedBrowser">
#   <div class="innerDiv" style="background: url('https://static.tacdn.com/img2/icons/64/bv_alert.gif') 12px 2px no-repeat;">
#    <span>
#     We noticed that you're using an unsupported browser. The Tripadvisor website may not display properly.We support the following browsers:
#    </span>
#    <br/>
#    <span dir="ltr">
#     Windows:
#     <span class="ui_link" onclick="ta.plc_unsupported_browser_messaging_0_handlers.openUrl('PFaSnEitiTI8LuSCMiutLSVLMVTJpcIzv')">
#      Internet Explorer
#     </span>
#     ,
#     <span class="ui_link" onclick="ta.plc_unsupported_browser_messaging_0_handlers.openUrl('PFaizCSccJ8LTSEVTixEL')">
#      Mozilla Firefox
#     </span>
#     ,
#     <span class="ui_link" onclick="ta.plc_unsupported_browser_messaging_0_handlers.openUrl('q5FyiiycV8LnGEiaV')">
# ...

# %%
spans = soup.find_all('span')
for span in spans:
    print(span.prettify())
# Out:
# <span>
#  We noticed that you're using an unsupported browser. The Tripadvisor website may not display properly.We support the following browsers:
# </span>
#
# <span dir="ltr">
#  Windows:
#  <span class="ui_link" onclick="ta.plc_unsupported_browser_messaging_0_handlers.openUrl('PFaSnEitiTI8LuSCMiutLSVLMVTJpcIzv')">
#   Internet Explorer
#  </span>
#  ,
#  <span class="ui_link" onclick="ta.plc_unsupported_browser_messaging_0_handlers.openUrl('PFaizCSccJ8LTSEVTixEL')">
#   Mozilla Firefox
#  </span>
#  ,
#  <span class="ui_link" onclick="ta.plc_unsupported_browser_messaging_0_handlers.openUrl('q5FyiiycV8LnGEiaV')">
#   Google Chrome
#  </span>
#  . Mac:
#  <span class="ui_link" onclick="ta.plc_unsupported_browser_messaging_0_handlers.openUrl('PFJ22cV8LtJTJESL')">
#   Safari
#  </span>
#  .
# </span>
# <span class="ui_link" onclick="ta.plc_unsupported_browser_messaging_0_handlers.openUrl('PFaSnEitiTI8LuSCMiutLSVLMVTJpcIzv')">
#  Internet Explorer
# </span>
#
# ...

# %%
Aas = soup.find_all('a')
for As in Aas:
    print(As.prettify())
# Out:
# <a class="subLink" href="/Tourism-g60823-Brookline_Massachusetts-Vacations.html">
#  Brookline Tourism
# </a>
# <a class="subLink" href="/Hotels-g60823-Brookline_Massachusetts-Hotels.html">
#  Brookline Hotels
# </a>
# <a class="subLink" href="/Hotels-g60823-Brookline_Massachusetts-Hotels.html">
#  Brookline Bed and Breakfast
# </a>
# <a class="subLink" href="/VacationRentals-g60823-Reviews-Brookline_Massachusetts-Vacation_Rentals.html">
#  Brookline Vacation Rentals
# </a>
# <a class="subLink" href="/Vacation_Packages-g60823-Brookline_Massachusetts-Vacations.html">
#  Brookline Vacation Packages
# </a>
# <a class="subLink" href="/Flights-g60823-Brookline_Massachusetts-Cheap_Discount_Airfares.html">
#  Flights to Brookline
# </a>
# <a class="subLink" href="/Restaurants-g60823-Brookline_Massachusetts.html">
#  Brookline Restaurants
# </a>
# <a class="subLink" href="/Attractions-g60823-Activities-Brookline_Massachusetts.html">
#  Things to Do in Brookline
# </a>
# ...

# %%
Qqs = soup.find_all('q')
for Qs in Qqs:
    print(Qs.prettify())
# Out:
# <q class="IRsGHoPm">
#  <span>
#   Yes, as if it was meant to be in some awkward and strange way, I finally visited the birthplace of the United States' 35th president last fall celebrating its 50th year anniversary of becoming part of the US National Park system. This despite earlier in the better part of the
#  </span>
#  <span>
#   …
#  </span>
# </q>
# <q class="IRsGHoPm">
#  <span>
#   Historical places, depicting the life from the best President the USA ever had. So much to see in the Boston area. Starting at the place where JFK was born, furnished like it was in 1917 is a vividly protected, "back in time". Later I went to the Kennedy graveyard and finally
#  </span>
#  <span>
#   …
#  </span>
# </q>
# <q class="IRsGHoPm">
#  <span>
# ...

# %%
tpads = soup.find_all('a')
for tpad in tpads:
    names = tpad.contents[0]
    fullLink = tpad.get('href')
    print(names)
    print(fullLink)
# Out:
# Brookline Tourism
# /Tourism-g60823-Brookline_Massachusetts-Vacations.html
# Brookline Hotels
# /Hotels-g60823-Brookline_Massachusetts-Hotels.html
# Brookline Bed and Breakfast
# /Hotels-g60823-Brookline_Massachusetts-Hotels.html
# Brookline Vacation Rentals
# /VacationRentals-g60823-Reviews-Brookline_Massachusetts-Vacation_Rentals.html
# Brookline Vacation Packages
# /Vacation_Packages-g60823-Brookline_Massachusetts-Vacations.html
# Flights to Brookline
# /Flights-g60823-Brookline_Massachusetts-Cheap_Discount_Airfares.html
# Brookline Restaurants
# /Restaurants-g60823-Brookline_Massachusetts.html
# Things to Do in Brookline
# /Attractions-g60823-Activities-Brookline_Massachusetts.html
# Brookline Travel Forum
# /ShowForum-g60823-i1970-Brookline_Massachusetts.html
# Brookline Photos
# /LocationPhotos-g60823-Brookline_Massachusetts.html
# Brookline Map
# /LocalMaps-g60823-Brookline-Area.html
# Brookline Travel Guide
# /Travel_Guide-g60823-Brookline_Massachusetts.html
# ...

# %%
#we know that all of our data can be found inside a table, so let's use <tr> to isolate the content that we want
#Not Working
trs = soup.find_all('tr')
for tr in trs:
    print(tr)

# %%
#Controlling the crawl rate
from time import sleep
from random import randint

for _ in range(0,5):
    print('No')
    sleep(randint(1,4))
# Out:
# No
# No
# No
# No
# No

# %%
#To get the reviewer name
container = soup.find('div', class_='_2fxQ4TOx')
print(len(container))
# Out:
# 1

# %%
container.span.a.text
# Out:
# 'Bryan A'

# %%
#To get the location of the Reviewer
Location_container = soup.find('div', class_='_1EpRX7o3')

# %%
Location_container.span.span.text
# Out:
# 'Concord, California'

# %%
Review_container = soup.find_all('div', class_='Dq9MAugU T870kzTX LnVzGwUB')
print(type(Review_container))
print(len(Review_container))
# Out:
# <class 'bs4.element.ResultSet'>
# 5

# %%
Review_container.div.span.a.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-5dc015e9c9be> in <module>
# ----> 1 Review_container.div.span.a.text
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2159         """Raise a helpful exception to explain a common code fix."""
#    2160         raise AttributeError(
# -> 2161             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2162         )
#
# AttributeError: ResultSet object has no attribute 'div'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
for con in Review_container:
    if con.find('div', class_='_3hDPbqWO') is not None:
        place_name = con.span.a
        place_names.append(place_name)

# %%
#This Tag will provide place name
Place_name = soup.find('div', class_='_3l73Kcue _1RqHi9Td')
print(type(Place_name))
# Out:
# <class 'bs4.element.Tag'>

# %%
Place_name.text
# Out:
# 'John F. Kennedy National Historic Site216 Reviews#2 of 11 things to do in BrooklineHistoric Sites'

# %%
#This tag will provide total reviews
Ratings_count = soup.find('div', class_='_1NKYRldB')
print(type(Ratings_count))
# Out:
# <class 'bs4.element.Tag'>

# %%
Ratings_count.text
# Out:
# '216 Reviews'

# %%
#This tag will provide Location of place
Location = soup.find('div', class_='v6CYB1gR')
print(type(Location))
# Out:
# <class 'bs4.element.Tag'>

# %%
Location.text
# Out:
# 'Contact83 Beals St, Brookline, MA 02446-6010Website+1 617-566-7937'

# %%
#This tag will provide ratings for specific location
Ratings = soup.find('div', class_='nf9vGX55')
print(type(Ratings))
# Out:
# <class 'bs4.element.Tag'>

# %%
print(len(Ratings))
# Out:
# 1

# %%
##This Tag will provide Review title
Review_title = soup.find('div', class_='glasR4aX')
print(type(Review_title))
# Out:
# <class 'bs4.element.Tag'>

# %%
Review_title.text
# Out:
# 'Finally! Well Worth it!'

# %%
##This Tag will provide Review Description
First_Review = soup.find('div', class_='_3hDPbqWO')
print(type(First_Review))
# Out:
# <class 'bs4.element.Tag'>

# %%
First_Review.q.span.text
# Out:
# "Yes, as if it was meant to be in some awkward and strange way, I finally visited the birthplace of the United States' 35th president last fall celebrating its 50th year anniversary of becoming part of the US National Park system. This despite earlier in the better part of the"

# %%
#Was trying to extract second half portion of Review
First_half_review = soup.find('q', class_='IRsGHoPm')
print(type(First_half_review))
# Out:
# <class 'bs4.element.Tag'>

# %%
First_half_review.span.text
# Out:
# "Yes, as if it was meant to be in some awkward and strange way, I finally visited the birthplace of the United States' 35th president last fall celebrating its 50th year anniversary of becoming part of the US National Park system. This despite earlier in the better part of the"

# %%
#Declare List to store scrape data
place_names = []
Locations = []
review_description = []

#Loop through pages 0-36
pages = [str(i) for i in range(1,36)]

#prepare the monitoring loop
start_time = time()
requestss = 0

#Iterate through the pages
for page in pages:
    ta = get("https://www.tripadvisor.com/Attraction_Review-g60823-d292269-Reviews"+ str(page)+"-John_F_Kennedy_National_Historic_Site-Brookline_Massachusetts.html", headers = headers)
    
    #pause the loop for 8-20 seconds
    sleep(randint(8,20))
    
    #monitor the requests
    requestss += 1
    elapsed_time = time() - start_time
    print('Request:{}; Frequency: {} requestss/s'.format(requestss, requestss/elapsed_time))
    clear_output(wait = True)
    
    #Show a warning if a non 200 status code is returned
    if ta.status_code != 200:
        warn('Request:{}; Status code: {}'.format(requestss, response.status_code))
        
    #break the loop if the requests exceed 40
    if requestss > 165:
        warn('Number of requests was greater than expected.')
        break
    
    #parse the response content into the beautiful soup object
    page = BeautifulSoup(ta.content, 'html.parser')
    
    #find the major tag peculiar to each review
    containers = page.find_all('div', class_='Dq9MAugU T870kzTX LnVzGwUB')
    
    for con in containers:
        place_name = con.find('div', class_='_3l73Kcue _1RqHi9Td')
        place_names.append(place_name)
        
        #location of reviewer
        Location = con.find('div', class_='_1EpRX7o3').span.text
        Locations.append(Location)
    
        First_Review = con.find('q', class_='IRsGHoPm').text
        review_description.append(First_Review)
# Out:
# Request:35; Frequency: 0.06565958400000779 requestss/s

# %%
#parse the data into a dataframe and store ina csv file
import pandas as pd
a={'place_name':place_names,'Reviewer_location':Locations,'Review_desc':review_description}
test_df = pd.DataFrame(a)
print(test_df.info())
test_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   place_name         0 non-null      object
#  1   Reviewer_location  175 non-null    object
#  2   Review_desc        175 non-null    object
# dtypes: object(3)
# memory usage: 4.2+ KB
# None
#     place_name        Reviewer_location  \
# 0         None      Concord, California
# 1         None        Borsbeek, Belgium
# 2         None       Brooklyn, New York
# 3         None       Renton, Washington
# 4         None  Bristol, United Kingdom
# ..         ...                      ...
# 170       None      Concord, California
# 171       None        Borsbeek, Belgium
# 172       None       Brooklyn, New York
# 173       None       Renton, Washington
# 174       None  Bristol, United Kingdom
#
#                                            Review_desc
# ...

# %%
test_df.to_csv('test_dff.csv')
