# %%
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen as ureq

# %%
URL = "https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_0_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_0_5_na_na_na&as-pos=0&as-type=RECENT&suggestionId=mobiles%7CMobiles&requestId=e97fad30-088a-4cb6-b8ac-88b7c851e5fb&as-searchtext=mobil"

# %%
myurl = requests.get(URL).text

# %%
soup = BeautifulSoup(myurl, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
#   <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
#   <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.dfde4d.css" rel="stylesheet"/>
#   <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
#    <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#    <meta content="website" property="og:type"/>
# ...

# %%
soup.title
# Out:
# <title>Mobiles - Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %%
soup.find_all("title")
# Out:
# [<title>Mobiles - Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>]

# %%
soup.body.script
# Out:
# <script nonce="8838653133693661505" type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "http://www.flipkart.com/",
#     "potentialAction": [{
#         "@type": "SearchAction",
#         "target": "http://www.flipkart.com/search?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#         },{
#         "@type": "SearchAction",
#         "target": "android-app://com.flipkart.android/flipkart/de_sq_seg_-search.flipkart.com-_{search_term_string}",
#         "query-input": "required name=search_term_string"
#     }]
# }
# </script>

# %%
Flip = soup.findAll("div",{"class":"_3ybBIU"})

# %%
len(Flip)
# Out:
# 1

# %%
Flipp = soup.findAll("div",{"class":"t-0M7P _2doH3V"})

# %%
len(Flipp)
# Out:
# 1

# %%
FlippK = soup.findAll("div",{"class":"_1UoZlX"})

# %%
len(FlippK)
# Out:
# 24

# %%
FlippK[0]
# Out:
# <div class="_1UoZlX"><a class="_31qSD5" href="/redmi-8-onyx-black-64-gb/p/itmaf669d074ff27?pid=MOBFKPYDZJQHGJXA&amp;lid=LSTMOBFKPYDZJQHGJXA5X8Q5G&amp;marketplace=FLIPKART&amp;srno=s_1_1&amp;otracker=AS_QueryStore_OrganicAutoSuggest_0_5_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_0_5_na_na_na&amp;fm=organic&amp;iid=6ba39bfa-66c0-4314-bc92-9fd2b8559943.MOBFKPYDZJQHGJXA.SEARCH&amp;ssid=oc5lg1b91s0000001580323908922&amp;qH=eb4af0bf07c16429" rel="noopener noreferrer" target="_blank"><div class="_3SQWE6"><div class="_1OCn9C"><div><div class="_3BTv9X" style="height:200px;width:200px"><img alt="Redmi 8 (Onyx Black, 64 GB)" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/></div></div></div><div class="_2lesQu"><div class="_1O_CiZ"><span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox"/><div class="_1p7h2j"></div></label></div></span><label class="_10TB-Q"><span>Add to Compare</span></label>
# ...

# %%
Container = FlippK[0]

# %%
Container.div.div.img
# Out:
# <img alt="Redmi 8 (Onyx Black, 64 GB)" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/>

# %%
Brand = Container.findAll("div",{"class":"_3wU53n"})

# %%
BrandName = Brand[0].text

# %%
specifications = Container.findAll("li",{"class":"tVe95H"})

# %%
BrandSpecification = specifications[0].text

# %%
pric = Container.findAll("div",{"class":"_3auQ3N _2GcJzG"})

# %%
price = pric[0].text

# %%
for flippo in FlippK:
    BrandName = Brand[0].text
    BrandSpecification = specifications[0].text
    price = pric[0].text

# %%
print("BrandName:" + BrandName)
print("BrandSpecification:" + BrandSpecification)
print("Price:" + price)
# Out:
# BrandName:Redmi 8 (Onyx Black, 64 GB)
# BrandSpecification:4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# Price:₹10,999

# %%
filename = "products.csv"
f = open(filename, "w")
headers = "Brandname, BrandSpecfication, Price"
f.write(headers)

# %%
f.close()
